# %% [markdown]
# # ADFuller Test to check if the series is stationary

# %%
from statsmodels.tsa.stattools import adfuller
from numpy import log
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/wwwusage.csv', names=['value'], header=0)
result = adfuller(df.value.dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -2.464240
# p-value: 0.124419

# %%
#p values is signiificant > 0.05, The series is not stationary

# %%
df.shape
# Out:
# (100, 1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# %matplotlib inline

# %%
df.plot()

# %%
import numpy as np, pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})

# Import data
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/wwwusage.csv', names=['value'], header=0)

# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(df.value); axes[0, 0].set_title('Original Series')
plot_acf(df.value, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(df.value.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(df.value.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(df.value.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(df.value.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %%
#We select the order of differncing to 2 to make the series stationary

# %% [markdown]
# How to find the order of the AR term (p)
# The next step is to identify if the model needs any AR terms. You can find out the required number of AR terms by inspecting the Partial Autocorrelation (PACF) plot.
#
# But what is PACF?
#
# Partial autocorrelation can be imagined as the correlation between the series and its lag, after excluding the contributions from the intermediate lags. So, PACF sort of conveys the pure correlation between a lag and the series. That way, you will know if that lag is needed in the AR term or not.

# %% [raw]
# So what is the formula for PACF mathematically?
#
# Partial autocorrelation of lag (k) of a series is the coefficient of that lag in the autoregression equation of Y.
#
# $$Yt = \alpha0 + \alpha1 Y{t-1} + \alpha2 Y{t-2} + \alpha3 Y{t-3}$$

# %% [raw]
# Any autocorrelation in a stationarized series can be rectified by adding enough AR terms. So, we initially take the order of AR term to be equal to as many lags that crosses the significance limit in the PACF plot.

# %%
# PACF plot of 1st differenced series
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(df.value.diff().diff()); axes[0].set_title('2nd order Differencing')
axes[1].set(ylim=(0,5))
plot_pacf(df.value.diff().diff().dropna(), ax=axes[1])

plt.show()

# %% [markdown]
# You can observe that the PACF lag 1 is quite significant since is well above the significance line. Lag 2 turns out to be a bit significant as well, slightly managing to cross the significance limit (blue region). So we can select the p value as 1 or 2.

# %% [markdown]
# How to find the order of the MA term (q)
# Just like how we looked at the PACF plot for the number of AR terms, you can look at the ACF plot for the number of MA terms. An MA term is technically, the error of the lagged forecast.
#
# The ACF tells how many MA terms are required to remove any autocorrelation in the stationarized series.
#
# Let’s see the autocorrelation plot of the differenced series.

# %%
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})


#df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/austa.csv')

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(df.value.diff().diff()); axes[0].set_title('2nd Differencing')
axes[1].set(ylim=(0,1.2))
plot_acf(df.value.diff().diff().dropna(), ax=axes[1])

plt.show()

# %%
#Lets tentatively fix the q to 2

# %% [markdown]
# # Lets Build the ARIMA Model

# %%
from statsmodels.tsa.arima_model import ARIMA

# 1,1,2 ARIMA Model
model = ARIMA(df.value, order=(2,2,2))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:               D2.value   No. Observations:                   98
# Model:                 ARIMA(2, 2, 2)   Log Likelihood                -252.561
# Method:                       css-mle   S.D. of innovations              3.176
# Date:                Fri, 15 Nov 2019   AIC                            517.122
# Time:                        17:14:06   BIC                            532.631
# Sample:                             2   HQIC                           523.395
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0230      0.245      0.094      0.926      -0.458       0.504
# ar.L1.D2.value     0.3730      0.232      1.606      0.112      -0.082       0.828
# ar.L2.D2.value    -0.3900      0.227     -1.718      0.089      -0.835       0.055
# ma.L1.D2.value    -0.1382      0.254     -0.545      0.587      -0.635       0.359
# ma.L2.D2.value    -0.0908      0.271     -0.335      0.738      -0.621       0.440
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.4783           -1.5283j            1.6014           -0.2017
# AR.2            0.4783           +1.5283j            1.6014            0.2017
# MA.1            2.6441           +0.0000j            2.6441            0.0000
# MA.2           -4.1661           +0.0000j            4.1661            0.5000
# -----------------------------------------------------------------------------

# %%
from statsmodels.tsa.arima_model import ARIMA

# 1,1,2 ARIMA Model
model = ARIMA(df.value, order=(1,1,1))#pd and q values
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.value   No. Observations:                   99
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -253.790
# Method:                       css-mle   S.D. of innovations              3.119
# Date:                Wed, 04 Sep 2019   AIC                            515.579
# Time:                        15:00:26   BIC                            525.960
# Sample:                             1   HQIC                           519.779
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             1.1205      1.286      0.871      0.386      -1.400       3.641
# ar.L1.D.value     0.6344      0.087      7.317      0.000       0.464       0.804
# ma.L1.D.value     0.5297      0.089      5.932      0.000       0.355       0.705
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.5764           +0.0000j            1.5764            0.0000
# MA.1           -1.8879           +0.0000j            1.8879            0.5000
# -----------------------------------------------------------------------------

# %%
# 1,2,1 ARIMA Model
model = ARIMA(df.value, order=(1,2,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:               D2.value   No. Observations:                   98
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -258.793
# Method:                       css-mle   S.D. of innovations              3.390
# Date:                Wed, 04 Sep 2019   AIC                            525.586
# Time:                        15:01:59   BIC                            535.926
# Sample:                             2   HQIC                           529.769
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0332      0.436      0.076      0.940      -0.821       0.887
# ar.L1.D2.value    -0.2660      0.182     -1.462      0.147      -0.623       0.091
# ma.L1.D2.value     0.6138      0.137      4.482      0.000       0.345       0.882
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -3.7599           +0.0000j            3.7599            0.5000
# MA.1           -1.6291           +0.0000j            1.6291            0.5000
# -----------------------------------------------------------------------------

# %%
# 1,1,2 ARIMA Model
model = ARIMA(df.value, order=(2,2,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:               D2.value   No. Observations:                   98
# Model:                 ARIMA(2, 2, 1)   Log Likelihood                -252.624
# Method:                       css-mle   S.D. of innovations              3.179
# Date:                Wed, 04 Sep 2019   AIC                            515.248
# Time:                        15:03:07   BIC                            528.173
# Sample:                             2   HQIC                           520.476
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0224      0.258      0.087      0.931      -0.484       0.529
# ar.L1.D2.value     0.3517      0.219      1.605      0.112      -0.078       0.781
# ar.L2.D2.value    -0.4573      0.094     -4.885      0.000      -0.641      -0.274
# ma.L1.D2.value    -0.1166      0.250     -0.466      0.642      -0.607       0.374
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.3846           -1.4279j            1.4788           -0.2081
# AR.2            0.3846           +1.4279j            1.4788            0.2081
# MA.1            8.5758           +0.0000j            8.5758            0.0000
# -----------------------------------------------------------------------------

# %%
from statsmodels.tsa.arima_model import ARIMA

# 1,1,2 ARIMA Model
model = ARIMA(df.value, order=(3,2,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:               D2.value   No. Observations:                   98
# Model:                 ARIMA(3, 2, 1)   Log Likelihood                -250.276
# Method:                       css-mle   S.D. of innovations              3.069
# Date:                Wed, 04 Sep 2019   AIC                            512.552
# Time:                        15:03:33   BIC                            528.062
# Sample:                             2   HQIC                           518.825
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0234      0.058      0.404      0.687      -0.090       0.137
# ar.L1.D2.value     1.1586      0.097     11.965      0.000       0.969       1.348
# ar.L2.D2.value    -0.6640      0.136     -4.890      0.000      -0.930      -0.398
# ar.L3.D2.value     0.3453      0.096      3.588      0.001       0.157       0.534
# ma.L1.D2.value    -1.0000      0.028    -36.302      0.000      -1.054      -0.946
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1703           -0.0000j            1.1703           -0.0000
# AR.2            0.3763           -1.5274j            1.5731           -0.2116
# AR.3            0.3763           +1.5274j            1.5731            0.2116
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------

# %%
# Actual vs Fitted
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
# Plot residual errors
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %% [markdown]
# # Forecasting n time steps

# %%
df.shape
# Out:
# (100, 1)

# %%
from statsmodels.tsa.stattools import acf

# Create Training and Test
train = df.value[:85]
test = df.value[85:]

# %%
test.shape
# Out:
# (15,)

# %%
# Build Model
model = ARIMA(train, order=(3, 2, 1))  
fitted = model.fit(disp=-1)  
print(fitted.summary())

# Forecast
fc, se, conf = fitted.forecast(15, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:               D2.value   No. Observations:                   83
# Model:                 ARIMA(3, 2, 1)   Log Likelihood                -214.248
# Method:                       css-mle   S.D. of innovations              3.153
# Date:                Wed, 04 Sep 2019   AIC                            440.497
# Time:                        15:12:18   BIC                            455.010
# Sample:                             2   HQIC                           446.327
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0483      0.084      0.577      0.565      -0.116       0.212
# ar.L1.D2.value     1.1386      0.109     10.399      0.000       0.924       1.353
# ar.L2.D2.value    -0.5923      0.155     -3.827      0.000      -0.896      -0.289
# ar.L3.D2.value     0.3079      0.111      2.778      0.007       0.091       0.525
# ma.L1.D2.value    -1.0000      0.035    -28.799      0.000      -1.068      -0.932
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1557           -0.0000j            1.1557           -0.0000
# AR.2            0.3839           -1.6318j            1.6763           -0.2132
# AR.3            0.3839           +1.6318j            1.6763            0.2132
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------

# %%
# Accuracy metrics
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    acf1 = acf(fc-test)[1]                      # ACF1
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'acf1':acf1, 
            'corr':corr, 'minmax':minmax})

forecast_accuracy(fc, test.values)

#> {'mape': 0.02250131357314834,
#>  'me': 3.230783108990054,
#>  'mae': 4.548322194530069,
#>  'mpe': 0.016421001932706705,
#>  'rmse': 6.373238534601827,
#>  'acf1': 0.5105506325288692,
#>  'corr': 0.9674576513924394,
#>  'minmax': 0.02163154777672227}
# Out:
# /Users/sumogroup/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)
# {'mape': 0.022501236426182805,
#  'me': 3.2307391309226223,
#  'mae': 4.548306448708833,
#  'mpe': 0.016420795050378335,
#  'rmse': 6.3732109105872645,
#  'acf1': 0.5105513836493297,
#  'corr': 0.9674576626455832,
#  'minmax': 0.021631479301249645}

# %% [markdown]
# # Automating model selection

# %%
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm

df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/wwwusage.csv', names=['value'], header=0)

model = pm.auto_arima(df.value, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=4, max_q=4, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Fit ARIMA: order=(1, 2, 1); AIC=525.586, BIC=535.926, Fit time=0.041 seconds
# Fit ARIMA: order=(0, 2, 0); AIC=533.474, BIC=538.644, Fit time=0.003 seconds
# Fit ARIMA: order=(1, 2, 0); AIC=532.437, BIC=540.192, Fit time=0.019 seconds
# Fit ARIMA: order=(0, 2, 1); AIC=525.893, BIC=533.648, Fit time=0.016 seconds
# Fit ARIMA: order=(2, 2, 1); AIC=515.248, BIC=528.173, Fit time=0.052 seconds
# Fit ARIMA: order=(2, 2, 0); AIC=513.459, BIC=523.798, Fit time=0.032 seconds
# Fit ARIMA: order=(3, 2, 1); AIC=512.552, BIC=528.062, Fit time=0.132 seconds
# Fit ARIMA: order=(4, 2, 1); AIC=519.293, BIC=537.387, Fit time=0.518 seconds
# Fit ARIMA: order=(3, 2, 0); AIC=515.284, BIC=528.209, Fit time=0.032 seconds
# Fit ARIMA: order=(3, 2, 2); AIC=514.514, BIC=532.609, Fit time=0.179 seconds
# Fit ARIMA: order=(4, 2, 2); AIC=516.557, BIC=537.237, Fit time=0.327 seconds
# Total fit time: 1.358 seconds
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                   D2.y   No. Observations:                   98
# Model:                 ARIMA(3, 2, 1)   Log Likelihood                -250.276
# Method:                       css-mle   S.D. of innovations              3.069
# Date:                Wed, 04 Sep 2019   AIC                            512.552
# Time:                        15:14:19   BIC                            528.062
# Sample:                             2   HQIC                           518.825
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0234      0.058      0.404      0.687      -0.090       0.137
# ar.L1.D2.y     1.1586      0.097     11.965      0.000       0.969       1.348
# ar.L2.D2.y    -0.6640      0.136     -4.890      0.000      -0.930      -0.398
# ar.L3.D2.y     0.3453      0.096      3.588      0.001       0.157       0.534
# ma.L1.D2.y    -1.0000      0.028    -36.302      0.000      -1.054      -0.946
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1703           -0.0000j            1.1703           -0.0000
# AR.2            0.3763           -1.5274j            1.5731           -0.2116
# AR.3            0.3763           +1.5274j            1.5731            0.2116
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------

# %%
# Forecast
n_periods = 24
fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = np.arange(len(df.value), len(df.value)+n_periods)

# make series for plotting purpose
fc_series = pd.Series(fc, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.plot(df.value)
plt.plot(fc_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("Final Forecast of WWW Usage")
plt.show()

# %% [markdown]
# # SEASONAL ARIMA

# %%
# Import
data = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'], index_col='date')

# Plot
fig, axes = plt.subplots(2, 1, figsize=(10,5), dpi=100, sharex=True)

# Usual Differencing
axes[0].plot(data[:], label='Original Series')
axes[0].plot(data[:].diff(1), label='Usual Differencing')
axes[0].set_title('Usual Differencing')
axes[0].legend(loc='upper left', fontsize=10)


# Seasinal Dei
axes[1].plot(data[:], label='Original Series')
axes[1].plot(data[:].diff(12), label='Seasonal Differencing', color='green')
axes[1].set_title('Seasonal Differencing')
plt.legend(loc='upper left', fontsize=10)
plt.suptitle('a10 - Drug Sales', fontsize=16)
plt.show()

# %%
smodel = pm.auto_arima(data, start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=12,
                         start_P=0, seasonal=True,
                         d=None, D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

smodel.summary()
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=534.818, BIC=551.105, Fit time=0.687 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=624.061, BIC=630.576, Fit time=0.018 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=596.068, BIC=609.098, Fit time=0.283 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=611.475, BIC=624.505, Fit time=0.213 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=554.542, BIC=574.087, Fit time=1.190 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 0, 12); AIC=559.407, BIC=572.437, Fit time=0.157 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 2, 12); AIC=536.817, BIC=556.362, Fit time=2.289 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=537.876, BIC=560.678, Fit time=3.096 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=529.829, BIC=549.374, Fit time=0.696 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=546.662, BIC=562.949, Fit time=0.281 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 1, 1, 12); AIC=531.827, BIC=554.630, Fit time=1.083 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=594.467, BIC=607.497, Fit time=0.214 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 1, 1, 12); AIC=528.448, BIC=554.507, Fit time=0.882 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 1, 1, 12); AIC=550.471, BIC=579.788, Fit time=1.941 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 1, 0, 12); AIC=550.615, BIC=573.418, Fit time=0.406 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 1, 2, 12); AIC=529.776, BIC=559.093, Fit time=3.191 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 1, 2, 12); AIC=518.565, BIC=551.140, Fit time=5.542 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 1, 2, 12); AIC=529.452, BIC=558.769, Fit time=4.851 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=518.184, BIC=547.501, Fit time=3.754 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 2, 12); AIC=545.610, BIC=568.413, Fit time=2.355 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(0, 1, 2, 12); AIC=530.574, BIC=556.634, Fit time=1.932 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 1, 2, 12); AIC=532.016, BIC=564.591, Fit time=3.650 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=549.632, BIC=575.692, Fit time=1.944 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=529.107, BIC=551.909, Fit time=0.674 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=524.202, BIC=550.262, Fit time=3.445 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 1, 2, 12); AIC=516.995, BIC=543.055, Fit time=3.400 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 1, 2, 12); AIC=529.704, BIC=552.507, Fit time=1.159 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 1, 2, 12); AIC=531.604, BIC=560.921, Fit time=2.868 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=551.748, BIC=574.550, Fit time=1.137 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=528.788, BIC=548.333, Fit time=0.364 seconds
# Total fit time: 53.709 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  204
# Model:             SARIMAX(3, 0, 0)x(1, 1, 2, 12)   Log Likelihood                -250.498
# Date:                            Sat, 24 Aug 2019   AIC                            516.995
# Time:                                    08:41:21   BIC                            543.055
# Sample:                                         0   HQIC                           527.550
#                                             - 204
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0205      0.027      0.748      0.454      -0.033       0.074
# ar.L1          0.0397      0.048      0.825      0.409      -0.055       0.134
# ar.L2          0.4330      0.039     11.152      0.000       0.357       0.509
# ar.L3          0.4346      0.056      7.782      0.000       0.325       0.544
# ar.S.L12       0.8393      0.121      6.965      0.000       0.603       1.075
# ma.S.L12      -1.6430      0.160    -10.285      0.000      -1.956      -1.330
# ma.S.L24       0.8395      0.126      6.646      0.000       0.592       1.087
# sigma2         0.6953      0.081      8.580      0.000       0.536       0.854
# ===================================================================================
# Ljung-Box (Q):                       63.30   Jarque-Bera (JB):               118.33
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):              13.06   Skew:                             0.44
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.74
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# # Forecast with SARIMA

# %%
# Forecast
n_periods = 24
fitted, confint = smodel.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = pd.date_range(data.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.plot(data)
plt.plot(fitted_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMA - Final Forecast of a10 - Drug Sales")
plt.show()

# %% [markdown]
# # SARIMAX

# %%
# Import Data
data = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'], index_col='date')

# %%
# Compute Seasonal Index
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

# multiplicative seasonal component
result_mul = seasonal_decompose(data['value'][-36:],   # 3 years
                                model='multiplicative', 
                                extrapolate_trend='freq')

seasonal_index = result_mul.seasonal[-12:].to_frame()
seasonal_index['month'] = pd.to_datetime(seasonal_index.index).month

# merge with the base data
data['month'] = data.index.month
df = pd.merge(data, seasonal_index, how='left', on='month')
df.columns = ['value', 'month', 'seasonal_index']
df.index = data.index  # reassign the index.

# %%
import pmdarima as pm

# SARIMAX Model
sxmodel = pm.auto_arima(df[['value']], exogenous=df[['seasonal_index']],
                           start_p=1, start_q=1,
                           test='adf',
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=None, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)

sxmodel.summary()
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=536.818, BIC=556.362, Fit time=0.770 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 12); AIC=626.061, BIC=635.834, Fit time=0.021 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 12); AIC=598.068, BIC=614.356, Fit time=0.332 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=613.475, BIC=629.762, Fit time=0.257 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=556.496, BIC=579.299, Fit time=1.381 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 0, 12); AIC=561.407, BIC=577.695, Fit time=0.192 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 2, 12); AIC=538.817, BIC=561.620, Fit time=2.632 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=539.908, BIC=565.968, Fit time=3.510 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=531.829, BIC=554.632, Fit time=0.861 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=548.662, BIC=568.207, Fit time=0.314 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(0, 1, 1, 12); AIC=533.827, BIC=559.887, Fit time=1.186 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=596.467, BIC=612.754, Fit time=0.246 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 1, 1, 12); AIC=530.448, BIC=559.765, Fit time=0.953 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 1, 1, 12); AIC=552.291, BIC=584.866, Fit time=2.384 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 1, 0, 12); AIC=552.615, BIC=578.675, Fit time=0.448 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 1, 2, 12); AIC=531.776, BIC=564.351, Fit time=3.488 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(1, 1, 2, 12); AIC=520.567, BIC=556.399, Fit time=5.816 seconds
# Fit ARIMA: order=(2, 0, 2) seasonal_order=(1, 1, 2, 12); AIC=527.461, BIC=560.036, Fit time=5.056 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=520.184, BIC=552.759, Fit time=4.282 seconds
# Fit ARIMA: order=(2, 0, 0) seasonal_order=(1, 1, 2, 12); AIC=547.610, BIC=573.670, Fit time=3.178 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(0, 1, 2, 12); AIC=532.574, BIC=561.891, Fit time=2.152 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(2, 1, 2, 12); AIC=534.016, BIC=569.848, Fit time=3.988 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(1, 1, 1, 12); AIC=552.059, BIC=581.376, Fit time=2.252 seconds
# Fit ARIMA: order=(3, 0, 1) seasonal_order=(0, 1, 1, 12); AIC=531.107, BIC=557.167, Fit time=0.813 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(1, 1, 2, 12); AIC=526.234, BIC=555.551, Fit time=3.934 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 1, 2, 12); AIC=518.995, BIC=548.313, Fit time=3.803 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 1, 2, 12); AIC=531.704, BIC=557.764, Fit time=1.308 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(2, 1, 2, 12); AIC=533.604, BIC=566.179, Fit time=3.040 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(1, 1, 1, 12); AIC=553.748, BIC=579.808, Fit time=1.674 seconds
# Fit ARIMA: order=(3, 0, 0) seasonal_order=(0, 1, 1, 12); AIC=530.788, BIC=553.591, Fit time=0.414 seconds
# Total fit time: 60.702 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  204
# Model:             SARIMAX(3, 0, 0)x(1, 1, 2, 12)   Log Likelihood                -250.498
# Date:                            Sat, 24 Aug 2019   AIC                            518.995
# Time:                                    08:45:12   BIC                            548.313
# Sample:                                         0   HQIC                           530.869
#                                             - 204
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0205      0.028      0.725      0.468      -0.035       0.076
# x1          6.671e-06   8.74e+04   7.64e-11      1.000   -1.71e+05    1.71e+05
# ar.L1          0.0396      0.048      0.822      0.411      -0.055       0.134
# ar.L2          0.4330      0.039     11.137      0.000       0.357       0.509
# ar.L3          0.4347      0.056      7.737      0.000       0.325       0.545
# ar.S.L12       0.8393      0.121      6.942      0.000       0.602       1.076
# ma.S.L12      -1.6431      0.161    -10.181      0.000      -1.959      -1.327
# ma.S.L24       0.8396      0.127      6.598      0.000       0.590       1.089
# sigma2         0.6953      0.082      8.524      0.000       0.535       0.855
# ===================================================================================
# Ljung-Box (Q):                       63.30   Jarque-Bera (JB):               118.35
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):              13.06   Skew:                             0.44
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.74
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Forecast
n_periods = 24
fitted, confint = sxmodel.predict(n_periods=n_periods, 
                                  exogenous=np.tile(seasonal_index.value, 2).reshape(-1,1), 
                                  return_conf_int=True)

index_of_fc = pd.date_range(data.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.plot(data['value'])
plt.plot(fitted_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMAX Forecast of a10 - Drug Sales")
plt.show()
